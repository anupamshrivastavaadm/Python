# %% [markdown]
# #Python File Handling

# %% [markdown]
# ##You Can Hide Text Messages in
#
# ##Images Using File Handling!
#
# 🔍 Did you know?
# You can append text to an image file —
#
# and it’ll still open normally as an image! But you can read
#
# the hidden text message using Python.

# %% [markdown]
# ![image (1) - Copy.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##🔧 Step 1: Hide the message

# %%
with open('/content/sample_data/image (1).jpg', 'ab') as f:
    f.write(b'\nSecretMessage: ABCDXYZ.')

# %% [markdown]
# 🧩 Problem:
#
# You used Python to embed a text message inside an
#
# image, but assume you have a question:
#
# "How can I tell just by looking at the image that it has
#
# hidden text data inside?"
#
# ✅ Answer:
#
# The image will look completely normal — you won’t see
#
# anything with your eyes because:
#
# - Image viewers (like Gallery, Preview, etc.) only read
#
#   the visual part of the image.
#
# - The data you append using open('image (1).jpg', 'ab') is
#
#   added after the image's end marker.
#
# - Viewers ignore anything that comes after that
#
#   marker.
#
# So even though the message is there, it’s invisible to the
#
# naked eye — but Python can still read it.

# %% [markdown]
# ##🔍 Step 2: Extract the message

# %%
with open('/content/sample_data/image (1).jpg', 'rb') as f:
    data = f.read()
    if b'SecretMessage:' in data:
        print(data.split(b'SecretMessage:')[-1].decode())
# Out:
#  ABCDXYZ.

# %% [markdown]
# What’s the Real Use of Hiding Text Messages in Images
#
# Using File Handling?
#
# This concept is based on steganography, and the idea has
#
# real-world applications too:
#
# 🛡️ 1. Cybersecurity & Ethical Hacking
#
# 📦 2. Data Watermarking & Ownership
#
# 🕵️ 3. Steganography
#
# 👨‍🏫 4. Teaching File Structures & Binary Manipulation
#
# 🎨 5. Creative Uses

# %% [markdown]
# # 👉👉👉 Follow Code_with_AS 👈👈👈
#
# #for more...
